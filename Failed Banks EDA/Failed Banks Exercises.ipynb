# %% [markdown]
# # Pandas Exercises

# %% [markdown]
# Time to test your new pandas skills!
#
# **NOTE: ALL TASKS MUST BE DONE IN AS LESS LINES OF PANDAS CODE AS POSSIBLE.**

# %% [markdown]
# **Import pandas and read in the banklist.csv file into a dataframe called banks.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('banklist.csv')

# %% [markdown]
# **Show the head of the dataframe**

# %%
df.head(10)
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %% [markdown]
# **What are the column names?**

# %%
# CODE HERE

# %%
df.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %% [markdown]
# **How many States (ST) are represented in this data set?**

# %%
# CODE HERE

# %%
df['ST'].nunique()
# Out:
# 44

# %% [markdown]
# **How many cities are represented in this data set?**

# %%
df['City'].nunique()
# Out:
# 424

# %% [markdown]
# **Get a list or array of all the states in the data set.**

# %%
# CODE HERE

# %%
np.array(df['ST'].unique())
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %% [markdown]
# **What are the top 5 states with the most failed banks?**

# %%
# CODE HERE

# %%
d1 = pd.DataFrame(df.groupby('ST').count().sort_values(by = 'Bank Name',ascending=False)['Bank Name'])
d1.columns = ['Count']
d1.reset_index(inplace=True)
d1
# Out:
#     ST  Count
# 0   GA     93
# 1   FL     75
# 2   IL     67
# 3   CA     41
# 4   MN     23
# 5   WA     19
# 6   AZ     16
# 7   MO     16
# 8   MI     14
# 9   TX     12
# 10  NV     12
# 11  WI     11
# 12  SC     10
# 13  PA     10
# 14  MD     10
# 15  CO     10
# 16  KS      9
# 17  UT      8
# 18  OH      8
# 19  NJ      7
# 20  TN      7
# 21  OK      7
# 22  AL      7
# 23  NC      7
# 24  OR      6
# 25  NY      5
# 26  VA      5
# 27  LA      4
# 28  PR      4
# 29  NM      3
# 30  AR      3
# 31  NE      3
# 32  IN      3
# 33  KY      2
# 34  MS      2
# 35  CT      2
# 36  ID      2
# 37  IA      2
# 38  HI      1
# 39  WV      1
# 40  NH      1
# 41  SD      1
# 42  MA      1
# 43  WY      1

# %%
plt.figure(figsize=(12,5))
sns.barplot(d1['ST'].head(),d1['Count'].head())

# %% [markdown]
# **Top cities with most failed banks?**

# %%
g5 = pd.DataFrame(df.groupby('City').count().sort_values(by = 'Bank Name',ascending=False)['Bank Name'])
g5.columns= ['Count']
g5.reset_index(inplace=True)
g5
# Out:
#                   City  Count
# 0              Chicago     18
# 1              Atlanta     10
# 2              Phoenix      6
# 3               Naples      5
# 4           Scottsdale      4
# 5           Alpharetta      4
# 6            Bradenton      4
# 7                Miami      4
# 8          Los Angeles      4
# 9            Las Vegas      4
# 10         Stockbridge      3
# 11           Henderson      3
# 12          Birmingham      3
# 13           Baltimore      3
# 14            Sarasota      3
# 15               Tampa      3
# 16           Woodstock      3
# 17           Milwaukee      3
# 18         Springfield      3
# 19           Asheville      3
# 20             Seattle      2
# 21        Coral Gables      2
# 22     Fort Lauderdale      2
# 23         Forest Lake      2
# 24           St. Louis      2
# 25    Farmington Hills      2
# 26             Ellijay      2
# 27           San Diego      2
# 28       San Francisco      2
# 29              Duluth      2
# ...

# %%
plt.figure(figsize=(12,5))
sns.barplot(g5['City'].head(),g5['Count'].head())

# %% [markdown]
# **What are the top 5 acquiring institutions?**

# %%
# CODE HERE

# %%
g4 = pd.DataFrame(df.groupby('Acquiring Institution').count().sort_values('Bank Name',ascending = False)['Bank Name'])
g4.columns = ['Count']
g4.reset_index(inplace=True)
g4
# Out:
#                            Acquiring Institution  Count
# 0                                    No Acquirer     31
# 1                   State Bank and Trust Company     12
# 2            First-Citizens Bank & Trust Company     11
# 3                                    Ameris Bank     10
# 4                                 U.S. Bank N.A.      9
# 5                      Community & Southern Bank      8
# 6                                Centennial Bank      7
# 7                             Stearns Bank, N.A.      7
# 8                             Bank of the Ozarks      7
# 9                                   Central Bank      6
# 10             CenterState Bank of Florida, N.A.      6
# 11                       MB Financial Bank, N.A.      6
# 12                      Republic Bank of Chicago      6
# 13                           Great Southern Bank      5
# 14                               U.S. Bank, N.A.      5
# 15              CertusBank, National Association      5
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot(g4['Acquiring Institution'].head(),g4['Count'].head())

# %% [markdown]
# **How many banks has the State Bank of Texas acquired? How many of them were actually in Texas?**

# %%
# CODE HERE
len(df[(df['Acquiring Institution'] == 'State Bank of Texas')])
# Out:
# 3

# %%
len(df[(df['Acquiring Institution'] == 'State Bank of Texas') & (df['ST'] == 'TX')])
# Out:
# 1

# %% [markdown]
# **What is the most common city in California for a bank to fail in?**

# %%
df[(df['ST'] == 'CA')].groupby('City').count().sort_values('Bank Name',ascending=False).head()['Bank Name']
# Out:
# City
# Los Angeles      4
# San Diego        2
# San Francisco    2
# Palm Desert      2
# La Jolla         2
# Name: Bank Name, dtype: int64

# %% [markdown]
# **How many failed banks don't have the word "Bank" in their name?**

# %%
# CODE HERE
df[df['Bank Name'].apply(lambda name:'Bank' not in name)].count()['Bank Name']
# Out:
# 14

# %% [markdown]
# **How many failed banks have "Company" in their name?**

# %%
df[df['Bank Name'].apply(lambda name: 'Company' in name)].count()['Bank Name']
# Out:
# 17

# %% [markdown]
# **How many bank names start with the letter 's' ?**

# %%
# CODE HERE
df[df['Bank Name'].apply(lambda name:name[0].lower() == 's')].count()['Bank Name']
# Out:
# 53

# %%
df[df['Bank Name'].apply(lambda name: 'State' in name)].count()['Bank Name']
# Out:
# 34

# %% [markdown]
# **How many CERT values are above 20000 ?**

# %%
# CODE HERE
df[df['CERT'] > 20000].count()['CERT']
# Out:
# 417

# %% [markdown]
# **How many bank names consist of just two words? (e.g. "First Bank" , "Bank Georgia" )**

# %%
# CODE HERE
df[df['Bank Name'].apply(lambda name:len(name.split()) == 2)].count()['Bank Name']
# Out:
# 114

# %%
sum(df['Bank Name'].apply(lambda name:len(name.split()) == 2))
# Out:
# 114

# %% [markdown]
# **Bonus: How many banks closed in the year 2008? (this is hard because we technically haven't learned about time series with pandas yet! Feel free to skip this one!**

# %%
# CODE HERE
sum(df['Closing Date'].apply(lambda date: date[-2:]) == '08')
# Out:
# 25

# %% [markdown]
# **How many banks were closed between 2007 and 2012?**

# %%
l1 = ['07','08','09','10','11','12']
len(df[df['Closing Date'].apply(lambda date: (date[-2:]) in l1)])
# Out:
# 468

# %%
g1 = df[df['Closing Date'].apply(lambda date: (date[-2:]) in l1)]
g1
# Out:
#                                              Bank Name              City  ST  \
# 61                        Community Bank of the Ozarks     Sunrise Beach  MO
# 62                             Hometown Community Bank         Braselton  GA
# 63                        Citizens First National Bank         Princeton  IL
# 64                            Heritage Bank of Florida              Lutz  FL
# 65                                           NOVA Bank            Berwyn  PA
# 66                                          Excel Bank           Sedalia  MO
# 67                        First East Side Savings Bank           Tamarac  FL
# 68                              GulfSouth Private Bank            Destin  FL
# 69                                   First United Bank             Crete  IL
# 70                                         Truman Bank         St. Louis  MO
# 71                               First Commercial Bank       Bloomington  MN
# ...

# %%
sns.scatterplot()

# %% [markdown]
# **How many banks were closed out every year?**

# %%
sns.boxplot(x='Closing Year',data=g2,palette='rainbow')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-703f08c879d1> in <module>()
# ----> 1 sns.boxplot(x='Closing Year',data=g2,palette='rainbow')
#
# c:\users\dell\py4e\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2235     kwargs.update(dict(whis=whis, notch=notch))
#    2236
# -> 2237     plotter.plot(ax, kwargs)
#    2238     return ax
#    2239
#
# c:\users\dell\py4e\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     547     def plot(self, ax, boxplot_kws):
#     548         """Make the plot."""
# --> 549         self.draw_boxplot(ax, boxplot_kws)
#     550         self.annotate_axes(ax)
#     551         if self.orient == "h":
#
# ...

# %%
df['Closing Year'] = [('20'+date[-2:]) for date in df['Closing Date']]
g2 = pd.DataFrame(df.groupby('Closing Year').count()['Bank Name'])
g2.columns = ['Count']
g2.reset_index(inplace=True)
g2
g2['Count'].describe()
# Out:
# count     16.000000
# mean      34.437500
# std       50.422176
# min        2.000000
# 25%        3.750000
# 50%        9.000000
# 75%       31.500000
# max      157.000000
# Name: Count, dtype: float64

# %%
plt.figure(figsize=(12,5))
sns.barplot(g2['Closing Year'],g2['Count'],data=g2)

# %% [markdown]
# **In which cities and how many banks were closed out every year?**

# %%
df.groupby(['Closing Year','City']).count()['Bank Name']
# Out:
# Closing Year  City
# 2000          Honolulu              1
#               Metropolis            1
# 2001          Hinsdale              1
#               Malta                 1
#               Manchester            1
# 2002          Alamo                 1
#               Atlanta               1
#               Boca Raton            1
#               Cheneyville           1
#               Miami                 1
#               Oakwood               1
#               Phoenix               1
#               Shelby Township       1
#               Sierra Blanca         1
#               Stamford              1
# 2003          Blanchardville        1
#               Philadelphia          1
#               Torrance              1
# 2004          Ephraim               1
#               Newark                1
#               Tallahassee           1
#               White Plains          1
# 2007          Alpharetta            1
#               Lakeview              1
# ...

# %%
df.groupby(['Closing Year','ST']).count()['Bank Name']
# Out:
# Closing Year  ST
# 2000          HI    1
#               IL    1
# 2001          IL    1
#               NH    1
#               OH    1
# 2002          AZ    1
#               CT    1
#               FL    2
#               GA    1
#               LA    1
#               MI    1
#               OH    1
#               TN    1
#               TX    1
# 2003          CA    1
#               PA    1
#               WI    1
# 2004          FL    1
#               NJ    1
#               NY    1
#               UT    1
# 2007          GA    1
#               OH    1
#               PA    1
# 2008          AR    1
#               CA    5
#               FL    2
#               GA    5
#               IL    1
#               KS    1
#                    ..
# 2013          WA    1
#               WI    2
# 2014          CA    1
#               FL    1
#               GA    1
#               ID    1
#               IL    5
#               MD    2
#               MN    1
# ...

# %%
df.groupby(['Closing Year','City','ST']).count()['Bank Name']
# Out:
# Closing Year  City                ST
# 2000          Honolulu            HI    1
#               Metropolis          IL    1
# 2001          Hinsdale            IL    1
#               Malta               OH    1
#               Manchester          NH    1
# 2002          Alamo               TN    1
#               Atlanta             GA    1
#               Boca Raton          FL    1
#               Cheneyville         LA    1
#               Miami               FL    1
#               Oakwood             OH    1
#               Phoenix             AZ    1
#               Shelby Township     MI    1
#               Sierra Blanca       TX    1
#               Stamford            CT    1
# 2003          Blanchardville      WI    1
#               Philadelphia        PA    1
#               Torrance            CA    1
# 2004          Ephraim             UT    1
#               Newark              NJ    1
#               Tallahassee         FL    1
# ...

# %% [markdown]
# **Variation of CERT number for the failed banks**

# %%
sns.distplot(df['CERT'])
# Out:
# c:\users\dell\py4e\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# **Which date were the most number of banks closed on?**

# %%
df.groupby('Closing Date').count().sort_values('Bank Name',ascending=False)['Bank Name']
# Out:
# Closing Date
# 30-Oct-09    9
# 20-Aug-10    8
# 16-Apr-10    8
# 2-Jul-09     7
# 18-Dec-09    7
# 22-Oct-10    7
# 24-Jul-09    7
# 23-Apr-10    7
# 23-Jul-10    7
# 23-Oct-09    7
# 19-Mar-10    7
# 30-Apr-10    7
# 4-Dec-09     6
# 15-Apr-11    6
# 17-Sep-10    6
# 29-Jan-10    6
# 16-Jul-10    6
# 17-Dec-10    6
# 6-Nov-09     5
# 31-Jul-09    5
# 30-Jul-10    5
# 22-Jan-10    5
# 14-Aug-09    5
# 26-Jun-09    5
# 20-Jul-12    5
# 29-Apr-11    5
# 27-Apr-12    5
# 28-May-10    5
# 4-Sep-09     5
# 21-Jan-11    4
#             ..
# 25-Sep-09    1
# 26-Jun-02    1
# 26-May-17    1
# 26-Oct-12    1
# 27-Feb-15    1
# 27-Jan-17    1
# 27-Jul-01    1
# 27-Jul-12    1
# 27-Jun-14    1
# 24-Oct-08    1
# 24-Jun-11    1
# 24-Jan-14    1
# 20-Apr-12    1
# 19-Dec-14    1
# 19-Mar-04    1
# 19-Sep-08    1
# 2-Aug-13     1
# 2-Feb-01     1
# 2-Feb-07     1
# 2-Mar-12     1
# 20-Feb-09    1
# 23-Sep-16    1
# 20-Nov-09    1
# 21-May-09    1
# 21-May-10    1
# 22-Aug-08    1
# ...

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# 5                               Harvest Community Bank          Pennsville
# 6                                          Allied Bank            Mulberry
# 7                         The Woodbury Banking Company            Woodbury
# 8                               First CornerStone Bank     King of Prussia
# 9                                   Trust Company Bank             Memphis
# 10                          North Milwaukee State Bank           Milwaukee
# ...

# %%
df['Closing Month'] = df['Closing Date'].apply(lambda x:x.split('-')[1])

# %%
df.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date  \
# 0   1802            United Fidelity Bank, fsb    26-May-17     1-Jun-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
# 2  58302                         Whitney Bank    28-Apr-17    23-May-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17
#
#   Closing Year Closing Month
# 0         2017           May
# ...

# %%
g3 = pd.DataFrame(df.groupby('Closing Month').count().sort_values('Bank Name',ascending=False)['Bank Name'])
g3.columns = ['Count']
g3.reset_index(inplace=True)
g3
# Out:
#    Closing Month  Count
# 0            Jul     74
# 1            Apr     59
# 2            Oct     58
# 3            Jan     51
# 4            Feb     44
# 5            May     43
# 6            Aug     41
# 7            Mar     40
# 8            Sep     37
# 9            Jun     35
# 10           Nov     35
# 11           Dec     34

# %%
plt.figure(figsize=(12,5))
sns.barplot(g3['Closing Month'],g3['Count'],data=g3)

# %%
df.groupby('Closing Month').count().sort_values('Bank Name',ascending=False)['Bank Name'].mean()
# Out:
# 45.916666666666664

# %%
df.groupby('Closing Year').count().sort_values('Bank Name',ascending=False)['Bank Name'].mean()
# Out:
# 34.4375

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# 5                               Harvest Community Bank          Pennsville
# 6                                          Allied Bank            Mulberry
# 7                         The Woodbury Banking Company            Woodbury
# 8                               First CornerStone Bank     King of Prussia
# 9                                   Trust Company Bank             Memphis
# 10                          North Milwaukee State Bank           Milwaukee
# ...

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# 5                               Harvest Community Bank          Pennsville
# 6                                          Allied Bank            Mulberry
# 7                         The Woodbury Banking Company            Woodbury
# 8                               First CornerStone Bank     King of Prussia
# 9                                   Trust Company Bank             Memphis
# 10                          North Milwaukee State Bank           Milwaukee
# ...
